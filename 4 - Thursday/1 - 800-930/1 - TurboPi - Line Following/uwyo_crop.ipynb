# %%
import uwyo_preprocessor as preprocessor

# %%
dataset = 'Data'
prep = preprocessor.preprocessor(name='prep')

# %%
prep.Copy_Crop(f'{dataset}/line_following/',
               f'{dataset}/crop/',
               divisions=4, 
               level=1)
# Out:
# [INFO] Processing 100 images from Data/line_following/
# [INFO] Creating 400 images at Data/crop/
#    400 /   400 | [====================]  100%

# %%
prep.Distribute_Data(original_location=f'{dataset}/negative/', 
                     training_location=f'{dataset}/training/', 
                     testing_location=f'{dataset}/testing/', 
                     split=0.8,
                     validation_location=f'{dataset}/validation/')

prep.Distribute_Data(original_location=f'{dataset}/positive/', 
                     training_location=f'{dataset}/training/', 
                     testing_location=f'{dataset}/testing/', 
                     split=0.8,
                     validation_location=f'{dataset}/validation/')
# Out:
# ...
# [INFO] Found 236 files at Data/negative/
# ...
#    236 /   236 | [====================]  100%
# ...
# [INFO] Found 164 files at Data/positive/
# ...
#
#    164 /   164 | [====================]  100%
